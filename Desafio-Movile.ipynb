# %% [markdown]
# # Desafio Movile
#
# Neste desafio, estudamos o problema de classificação de spams em mensagens de SMS.
#
# Foram fornecidas pela Wavy amostras de mensagens de diferentes operadoras.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
pd.set_option('display.max_colwidth', -1)
import warnings
warnings.filterwarnings('ignore')
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
dataset = pd.read_csv('SPAM Data _ Akari - SPAM Data.csv')
original_dataset = dataset.copy()

# %%
dataset.head(10)
# Out:
#       vendor  \
# 0  superible
# 1  superible
# 2  mailserr
# 3  zootude
# 4  zootude
# 5  zootude
# 6  zootude
# 7  zootude
# 8  zootude
# 9  zootude
#
#                                                                                                                                                            mensagem  \
# 0   A OI esta com 1 oferta Especial para sua nova Empresa adquira hj mesmo telefone Fixo + Banda Larga, ligue 0800 942 5512 ou Responda ok q entraremos em contato
# 1   A OI esta com uma oferta Especial para sua nova Empresa adquira hoje mesmo Fixo + Banda Larga, ligue 0800 942 5512 ou Responda ok que entraremos em contato.
# 2   Parabens, seu CNPJ esta ativo! A Oi tem OFERTA EXCLUSIVA em voz e internet para sua empresa. Responda OK que ligamos para voce ou ligue 0800 291 2253
# 3  1/2 Para voce receber as nossas ofertas adicione nosso numero 22992872243 em seus contatos e nos mande um oi. De 24 a 26 SUPER SEMANA DA LIMPEZA NO SUPERMERCADO
# 4  2/2  a CLARO! Ja deixei todo mundo avisado por aqui para soltar a promocao para esse codigo! Corre que a oferta vai ate as 20:00hs. Vem para NET!
# 5  2/2 a CLARO! Ja deixei todo mundo avisado por aqui para soltar a promocao para esse codigo! Corre que a oferta vai ate as 20:00hs. Vem para NET!
# 6  A claro tem oferta imperdivel para voce 3,5GB internet ligacoes ilimitadas p qualquer operadora apenas R$42,99 Venha a Claro em Tres Rios, altere seu plano hoje
# 7  A claro tem oferta imperdivel para voce 3,5GB internet ligacoes locais ilimitadas por R$42,99 Venha a loja Claro no Shopping Estacao Itaipava e altere seu plano
# 8  A claro tem oferta imperdivel para voce 3,5GB internet ligacoes locais ilimitadas R$42,99 Venha a Claro em Barra do Pirai R Gov Portela e altere seu plano hoje
# 9  A claro tem oferta imperdivel para voce, 3,5GB internet ligacoes ilimitadas p qualquer operadora apenas R$42,99 Venha a Claro em Teresopolis e altere seu plano
#
#   destino   spam  total
# 0  OI      False  1667
# 1  OI      False  2130
# 2  OI      False  909
# 3  NaN     False  241
# 4  CLARO   False  3863
# 5  CLARO   False  101
# 6  CLARO   False  1311
# 7  CLARO   False  797
# 8  CLARO   False  932
# 9  CLARO   False  1895

# %% [markdown]
# Na amostra acima, podemos ver que temos 5 features:
# * Vendor: Nome da empresa que enviou a mensagem
# * Mensagem: texto da mensagem
# * Destino: Operadora do destinatário da mensagem
# * Spam: se foi classificada como spam (true) ou não (false)
# * Total: Quantidade de cópias da mensagem enviadas

# %% [markdown]
# ## Abordagens
#
# Existem inúmeras formas de explorar o problema. Primeiro, devemos olhar bem as características dos nossos dados.

# %%
dataset['destino'].value_counts()
# Out:
# OI        74
# TIM       50
# CLARO     46
# VIVO      9
# NEXTEL    8
# Oi        6
# Name: destino, dtype: int64

# %%
dataset['spam'].value_counts()
# Out:
# False    991
# True     6
# Name: spam, dtype: int64

# %% [markdown]
# Aqui temos um problema em que uma classe (negativa) é muito mais predominante do que a outra (positiva). Casos assim não são triviais de serem solucionados. Vamos então primeiramente explorar os dados e analisar uma possível solução.
#
# Podemos começar vendo o que temos nesses SMSs classificados como spam

# %%
dataset.loc[dataset['spam'] == True]
# Out:
#        vendor  \
# 772  mailserr
# 783  quasiyo
# 785  quasiyo
# 786  quasiyo
# 787  quasiyo
# 788  quasiyo
#
#                                                                                                                                                             mensagem  \
# 772  OI. Temos uma OFERTA especial de CELULAR ILIMITADO para todo BRASIL + 10GB de INTERNET. responda OK que retornarmos para voce ou ligue 0800 291 2253
# 783  Ola, somos da TIM! Parabens! Seu chip esta ativado, realize uma ligacao de 30 segundos para confirmar o funcionamento. Digite se ja esta utilizando, 2 se nao.
# 785  Ola, somos da TIM! Seu chip foi ativado e liberado para fazer ligacao. Utilize com urgencia, p confirmar o sinal! Digite 1 se ja esta utilizando, 2 se nao.
# 786  Ola, somos da TIM! Seu chip foi ativado e liberado para fazer ligacao. Utilize com urgencia, p confirmar o sinal! Digite 1 se ja esta utilizando, 2 se nao.
# 787  Ola, somos da TIM! Seu chip ja foi ativado e esta gerando fatura. Digite 1 se ja realizou alguma ligacao com seu chip novo, 2 se nao.
# 788  Ola, somos da TIM! Verificamos que voce ainda nao utilizou seu chip, e estamos gerando fatura! Faca uma ligacao com urgencia usando o seu chip da TIM.
#
#     destino  spam  total
# 772  NaN     True  2276
# 783  NaN     True  495
# 785  NaN     True  1041
# 786  NaN     True  458
# 787  NaN     True  283
# 788  NaN     True  193

# %% [markdown]
# Uma possível solução seria propor uma aumentação de dados. Como uma mensagem de propaganda de uma operadora enviada para outra operadora é considerado um spam, podemos usar isso como estratégia para aumentar os dados:
#
# Primeiro podemos criar cópias de ofertas da Oi para outras operadoras e colocá-las como exemplos de spams

# %%
dataset.loc[(original_dataset['destino'] == 'CLARO')]
# Out:
#        vendor  \
# 4    zootude
# 5    zootude
# 6    zootude
# 7    zootude
# 8    zootude
# 9    zootude
# 10   centigen
# 30   zootude
# 43   zootude
# 139  difize
# 140  difize
# 141  centigen
# 142  difize
# 143  centigen
# 144  difize
# 145  centigen
# 146  centigen
# 147  zootude
# 148  difize
# 149  centigen
# 150  difize
# 151  zootude
# 152  difize
# 153  centigen
# 154  difize
# 155  centigen
# 413  centigen
# 421  zootude
# 543  difize
# 544  centigen
# 545  centigen
# 546  centigen
# 773  quasiyo
# 774  quasiyo
# 775  quasiyo
# 776  quasiyo
# 777  zootude
# 797  centigen
# 830  difize
# 831  zootude
# 837  zootude
# 917  mailserr
# 923  zootude
# 950  mailserr
# 969  difize
# 983  centigen
#
#                                                                                                                                                              mensagem  \
# 4    2/2  a CLARO! Ja deixei todo mundo avisado por aqui para soltar a promocao para esse codigo! Corre que a oferta vai ate as 20:00hs. Vem para NET!
# 5    2/2 a CLARO! Ja deixei todo mundo avisado por aqui para soltar a promocao para esse codigo! Corre que a oferta vai ate as 20:00hs. Vem para NET!
# 6    A claro tem oferta imperdivel para voce 3,5GB internet ligacoes ilimitadas p qualquer operadora apenas R$42,99 Venha a Claro em Tres Rios, altere seu plano hoje
# 7    A claro tem oferta imperdivel para voce 3,5GB internet ligacoes locais ilimitadas por R$42,99 Venha a loja Claro no Shopping Estacao Itaipava e altere seu plano
# 8    A claro tem oferta imperdivel para voce 3,5GB internet ligacoes locais ilimitadas R$42,99 Venha a Claro em Barra do Pirai R Gov Portela e altere seu plano hoje
# 9    A claro tem oferta imperdivel para voce, 3,5GB internet ligacoes ilimitadas p qualquer operadora apenas R$42,99 Venha a Claro em Teresopolis e altere seu plano
# 10   A Claro tem planos para sua empresa economizar! 5GB + Ligacoes ILIMITADAS por R$72,30/mes! Responda sim e receba um contato AGORA!
# 30   ADRIANA, a Claro tem uma oferta para voce. Ligue agora 1052 e descubra.
# 43   ALEXANDRE, a Claro tem uma oferta para voce. Ligue agora 1052 e descubra.
# 139  CLARO CONTROLE Traga sua linha e tenha o 4G mais rapido do brasil + Ligacoes ILIMITADAS e  GANHE uma linha claro fixo apenas 72,80 responda SIM OU 0800 042 0177
# 140  CLARO: ANA vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 141  CLARO: ANA vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 142  CLARO: ANTONIO vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 143  CLARO: ANTONIO vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 144  CLARO: FRANCISCO vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 145  CLARO: FRANCISCO vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 146  CLARO: JOAO vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 147  CLARO: JOSE  voce tem direito a uma oferta especial da CLARO, em alguns minutos seu telefone vai tocar, nao deixe de atender, voce nao pode perder ;)
# 148  CLARO: JOSE vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 149  CLARO: JOSE vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 150  CLARO: JOSE vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/j59Tfk
# 151  CLARO: MARIA  voce tem direito a uma oferta especial da CLARO, em alguns minutos seu telefone vai tocar, nao deixe de atender, voce nao pode perder ;)
# 152  CLARO: MARIA vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 153  CLARO: MARIA vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 154  CLARO: MARIA vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/j59Tfk
# 155  CLARO: vc tem Descontos Exclusivos para Celulares e Planos. Receba em Casa. Tudo por WhatsApp click https://goo.gl/iHLLAj
# 413  Ligacoes ilmitadas + 5GB Internet 4.5G mais rapida do Brasil apenas RS65,99 na CLARO EMPRESAS. Whats do Consultor 011993507145 ou www.turboempresas.com.br
# 421  LUCAS pra voce cliente NET o CELULAR CLARO tem 16 GIGA de INTERNET + Chamadas ILIMITADAS p/ todo Brasil por apenas 119,90. Ligue 08007222233 e saiba como
# 543  OFERTA CLARO TV 235 CANAIS HD,INTERNET ILIMITADA,CHIP GRATUITO C/ WHATSAPP ILIMITADO,A40 MIL FILMES E SERIES E COPA DO MUNDO NO NOW AALIGUE GRATIS 0800 (1/2)
# 544  Oferta CLARO! Planos de voz ilimitado e internet 4GB a partir de 54,90 e  TV a partir de 49,90. Vai ficar fora dessa? Ligue 96 8407 3249 / 984073250 / 984072361
# 545  OFERTA CLARO! Planos de voz ilimitado e internet 4GB a partir de 54,90 e TV a partir de 49,90. Vai ficar fora dessa?  Ligue 96-98407324 / 984073250 / 984072361
# 546  Oferta CLARO! Planos de voz ilimitado e internet 4GB a partir de 54,90 e TV a partir de 49,90. Vai ficar fora dessa? Ligue 96 984073249 / 984073250 / 984072361
# 773  Ola ANA, so hoje a CLARO TV tem aprovado no seu CPF plano com mais de 130 canais e 2 pontos por 89,90/mes. Instalacao GRATIS. ligue 0800 042 0242
# 774  Ola JOSE, so hoje a CLARO TV tem aprovado no seu CPF plano com mais de 130 canais e 2 pontos por 89,90/mes. Instalacao GRATIS. ligue 0800 042 0242
# 775  Ola MARIA, so hoje 11/06/18 a CLARO TV tem aprovado no seu CPF plano com mais de 130 canais e 2 pontos por 89,90/mes. Instalacao GRATIS. ligue 0800 042 0242
# 776  Ola MARIA, so hoje a CLARO TV tem aprovado no seu CPF plano com mais de 130 canais e 2 pontos por 89,90/mes. Instalacao GRATIS. ligue 0800 042 0242
# 777  Ola Sou a Fabiana da Claro Empresas. Seu Plano Claro empresas esta apto a novas condicoes. Gostaria de receber uma proposta de renovacao?
# 797  Parabens Cliente Etica, Claro Empresas!Venha ser cliente NET agora tambem, com muito mais vantagens. 5MB + Fixo ilimitado local por 69,99. Valor fixo, s (1/2)
# 830  PROMOCAO CLARO TV 235 CANAIS + CHIP ILIMITADO WHATSAPP GRATUITO, ACLARO NOW COM 40 MIL FILMES E SERIE GRATIS + COPA DO MUNDO LIGUE GRATIS 08008102121
# 831  Que tal economizar aquela grana e ainda ficar super conectado? A Claro tem a oferta ideal para voce, que gosta de economizar e se manter atualizado!
# 837  ra a CLARO! Ja deixei todo mundo avisado por aqui para soltar a promocao para esse codigo! Corre que a oferta vai ate as 20:00hs. Vem para NET! (2/2)
# 917  So na Claro voce fala com qualquer operadora ainda tem muita internet pra navegar,whast liberado vem pra Rocell e comprova Rua:ANDRADAS,392 WHAST 55991282580
# 923  Sr usuario, CLARO le solicita realizar HOY el pago de su obligacion, recuerde que la mora genera suspension/afecta su historial crediticio. Si ya pago omita SMS
# 950  Traga seu numero para CLARO ganhe mais internet para navegar, Whastapp a vontade, ligacoes ILIMITADAS para todo Brasil. Rocell Digital  whastapp 55991282580
# 969  Venha conferir os descontos que voce tem no seu plano J1mini por apenas 279,00 ou J5prime por apenas 540,00.CLARO AO LADO DA MARISA NO SHOPPING TABOAOALEX
# 983  VOCE ESTA INSSATISFEITO COM A SUA OPERADORA DE CELULAR? VENHA NA LOJA APARECIDINHO ELETRO QUE PASSAMOS O SEU NUMERO PARA A CLARO COM PLANO DE 19,99 POR MES.
#
#     destino   spam  total
# 4    CLARO   False  3863
# 5    CLARO   False  101
# 6    CLARO   False  1311
# 7    CLARO   False  797
# 8    CLARO   False  932
# 9    CLARO   False  1895
# 10   CLARO   False  770
# 30   CLARO   False  198
# 43   CLARO   False  131
# 139  CLARO   False  15841
# 140  CLARO   False  101
# 141  CLARO   False  143
# 142  CLARO   False  110
# 143  CLARO   False  167
# 144  CLARO   False  113
# 145  CLARO   False  175
# 146  CLARO   False  116
# 147  CLARO   False  166
# 148  CLARO   False  237
# 149  CLARO   False  287
# 150  CLARO   False  192
# 151  CLARO   False  351
# 152  CLARO   False  466
# 153  CLARO   False  1607
# 154  CLARO   False  261
# 155  CLARO   False  796
# 413  CLARO   False  121
# 421  CLARO   False  115
# 543  CLARO   False  275
# 544  CLARO   False  215
# 545  CLARO   False  293
# 546  CLARO   False  508
# 773  CLARO   False  141
# 774  CLARO   False  158
# 775  CLARO   False  119
# 776  CLARO   False  334
# 777  CLARO   False  1054
# 797  CLARO   False  185
# 830  CLARO   False  142
# 831  CLARO   False  5009
# 837  CLARO   False  152
# 917  CLARO   False  667
# 923  CLARO   False  2689
# 950  CLARO   False  624
# 969  CLARO   False  109
# 983  CLARO   False  114

# %% [markdown]
# Podemos copiar algumas mensagens para outras operadoras:

# %%
def cria_spam(aumentacao, destino):
    global dataset
    aumentacao['spam'] = True

    if destino != 'OI':
        aumentacao['destino'] = 'OI'
        dataset = dataset.append(aumentacao)   
        
    if destino != 'CLARO':
        aumentacao['destino'] = 'CLARO'
        dataset = dataset.append(aumentacao)
    
    if destino != 'TIM':
        aumentacao['destino'] = 'TIM'
        dataset = dataset.append(aumentacao)
        
    if destino != 'VIVO':
        aumentacao['destino'] = 'VIVO'
        dataset = dataset.append(aumentacao)
        
    if destino != np.nan:
        aumentacao['destino'] = np.nan
        dataset = dataset.append(aumentacao)

# %%
dataset = original_dataset.copy()

aumentacao = original_dataset.loc[(original_dataset['destino'] == 'OI') & (original_dataset['mensagem'].str.contains('sua nova Empresa') | original_dataset['mensagem'].str.contains('Responda SIM'))]
cria_spam(aumentacao, 'OI')

aumentacao = original_dataset.loc[(original_dataset['destino'] == 'TIM') & (original_dataset['mensagem'].str.contains('condicoes') | original_dataset['mensagem'].str.contains('responda Sim') | original_dataset['mensagem'].str.contains('RESP: SIM') | original_dataset['mensagem'].str.contains('digite SIM'))]
cria_spam(aumentacao, 'TIM')

aumentacao = original_dataset.loc[(original_dataset['destino'] == 'VIVO') & (original_dataset['mensagem'].str.contains('Venha') | original_dataset['mensagem'].str.contains('Responda'))]
cria_spam(aumentacao, 'VIVO')

aumentacao = original_dataset.loc[(original_dataset['destino'] == 'CLARO') & (original_dataset['mensagem'].str.contains('GRATIS') |original_dataset['mensagem'].str.contains('oferta') | original_dataset['mensagem'].str.contains('Responda'))]
cria_spam(aumentacao, 'CLARO')

# %%
dataset['spam'].value_counts()
# Out:
# False    991
# True     378
# Name: spam, dtype: int64

# %% [markdown]
# Agora que fizemos a aumentação de dados, podemos transformar as mensagens em vetores usando o TfidfVectorizer do sklearn. Notei também que não há relação com a empresa que enviou a mensagem, nem o número de cópias da mensagem, podemos então descartar essas features.

# %%
label = dataset['spam']
label = np.array(label)
data = dataset.drop(['spam', 'vendor', 'total'], axis=1)
data = data.fillna('TODAS')
data = np.array(data)


ops = {'OI': 0, 'VIVO': 1, 'TIM': 2, 'CLARO': 3, 'TODAS': 4, 'NEXTEL': 5, 'Oi':0}

operadora = np.zeros((len(data), 6))
for i in range(len(data)):
    operadora[i][ops[data[i][1]]] = 1

data = np.column_stack((data[:,0], operadora))

print(data.shape)

tfidf = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word', stop_words=['e', 'ou','a','o','para','de','da','do','na','em','no'],ngram_range=(1,1))
data[:,0] = tfidf.fit_transform(data[:,0])

#Separar em treino e teste aleatoriamente
X_train, X_test, y_train, y_test =  train_test_split(data, label, test_size=0.15, random_state=5)

#Separar em treino e validação
X_train, X_valid, y_train, y_valid =  train_test_split(X_train, y_train, test_size=0.3, random_state=5)


print(y_train.shape)
print(X_train.shape)
# Out:
# (1369, 7)
# (814,)
# (814, 7)

# %% [markdown]
# Agora que temos os dados preparados, podemos aplicar algum método para definir se os SMS são ou não spams. Iremos aplicar aqui uma simples regressão linear para reduzir tempo e custo computacional.

# %%
from sklearn.linear_model import LinearRegression
regressao = LinearRegression().fit(X_train, y_train)
# regressao.score(X_valid, y_valid)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-458-8405d554c5f0> in <module>()
#       1 from sklearn.linear_model import LinearRegression
# ----> 2 regressao = LinearRegression().fit(X_train, y_train)
#       3 # regressao.score(X_valid, y_valid)
#
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: setting an array element with a sequence.

# %%
y_train
# Out:
# array([False, False, False, False, False, False, False, False,  True,
#        False,  True, False,  True,  True,  True,  True, False, False,
#         True, False, False, False, False, False, False, False, False,
#         True, False,  True, False, False, False, False, False, False,
#        False,  True, False,  True, False,  True,  True,  True,  True,
#        False,  True,  True,  True, False, False, False, False, False,
#        False, False, False, False,  True, False, False,  True, False,
#        False, False, False, False,  True,  True, False,  True, False,
#        False,  True,  True, False, False, False, False, False,  True,
#        False, False,  True,  True, False, False, False,  True,  True,
#         True, False, False, False, False,  True, False, False, False,
#         True, False, False, False,  True, False,  True,  True, False,
#        False, False, False,  True,  True, False,  True, False, False,
#         True, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False,  True, False, False, False, False, False, False,
#         True, False,  True, False, False,  True,  True, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False,  True,  True, False, False,  True, False,  True, False,
#        False, False, False, False,  True, False, False,  True, False,
#        False, False,  True,  True, False, False, False,  True,  True,
#        False, False, False, False,  True,  True, False,  True, False,
#         True,  True, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False,  True, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False,  True, False,  True,  True, False,
#         True, False, False, False,  True,  True, False,  True, False,
#         True, False,  True, False, False, False, False,  True, False,
#         True, False, False,  True,  True, False, False,  True,  True,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False,  True, False, False, False,
#         True,  True,  True, False, False, False, False,  True,  True,
#        False, False, False, False,  True, False, False, False, False,
#        False, False,  True, False, False, False,  True, False, False,
#        False, False, False,  True, False, False, False, False,  True,
#         True, False,  True,  True, False,  True, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#         True,  True, False, False, False, False,  True, False, False,
#         True,  True, False, False, False, False,  True, False,  True,
#        False, False, False, False, False,  True,  True, False,  True,
#        False, False, False, False, False,  True,  True, False, False,
#        False,  True,  True, False, False, False, False,  True, False,
#        False, False,  True,  True, False,  True,  True, False,  True,
#        False, False,  True, False, False,  True,  True, False, False,
#         True, False,  True,  True, False,  True, False,  True, False,
#         True, False, False, False, False, False, False,  True, False,
#        False, False, False,  True, False, False, False,  True, False,
#         True, False, False, False, False,  True, False, False, False,
#         True, False, False,  True, False, False, False, False, False,
#         True,  True, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False,  True,  True, False,  True, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False,  True,  True,  True, False,  True,  True,
#         True, False,  True, False, False,  True, False, False,  True,
#        False,  True, False, False, False, False, False, False, False,
#         True, False,  True, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False,  True,
#         True, False, False,  True,  True,  True, False,  True, False,
#        False,  True, False, False, False,  True, False,  True, False,
#         True, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False,  True,
#        False, False, False, False, False,  True, False,  True,  True,
#        False,  True,  True, False, False,  True, False, False, False,
#         True, False, False,  True, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False,  True,
#         True, False, False, False, False,  True, False, False, False,
#        False, False,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True,  True,  True,  True, False, False, False,  True,  True,
#        False, False, False,  True, False, False,  True,  True, False,
#        False, False, False,  True, False, False,  True, False, False,
#        False, False, False, False, False, False, False,  True, False,
#         True, False, False, False, False,  True, False, False,  True,
#        False, False, False,  True, False,  True, False, False, False,
#         True, False, False, False, False,  True, False, False, False,
#         True,  True, False, False,  True,  True, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False,  True, False,  True, False,
#        False, False, False, False,  True,  True, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#         True, False,  True, False, False, False, False, False, False,
#         True, False,  True,  True, False, False, False, False, False,
#        False, False, False,  True,  True, False, False,  True, False,
#        False,  True, False, False])

# %%
y_train.shape
# Out:
# (814,)

# %%
x = y_train.reshape((814,1)).transpose()

# %%
x
# Out:
# array([[False, False, False, False, False, False, False, False,  True,
#         False,  True, False,  True,  True,  True,  True, False, False,
#          True, False, False, False, False, False, False, False, False,
#          True, False,  True, False, False, False, False, False, False,
#         False,  True, False,  True, False,  True,  True,  True,  True,
#         False,  True,  True,  True, False, False, False, False, False,
#         False, False, False, False,  True, False, False,  True, False,
#         False, False, False, False,  True,  True, False,  True, False,
#         False,  True,  True, False, False, False, False, False,  True,
#         False, False,  True,  True, False, False, False,  True,  True,
#          True, False, False, False, False,  True, False, False, False,
#          True, False, False, False,  True, False,  True,  True, False,
#         False, False, False,  True,  True, False,  True, False, False,
#          True, False, False, False, False, False,  True, False, False,
#         False, False, False, False, False, False, False, False, False,
#          True, False,  True, False, False, False, False, False, False,
#          True, False,  True, False, False,  True,  True, False, False,
#         False, False,  True, False, False, False, False,  True, False,
#         False,  True,  True, False, False,  True, False,  True, False,
#         False, False, False, False,  True, False, False,  True, False,
#         False, False,  True,  True, False, False, False,  True,  True,
#         False, False, False, False,  True,  True, False,  True, False,
#          True,  True, False, False, False,  True, False, False, False,
#         False, False, False, False, False, False, False,  True, False,
#         False, False, False, False, False, False,  True, False, False,
#          True, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False,  True,
#         False, False, False, False,  True, False,  True,  True, False,
#          True, False, False, False,  True,  True, False,  True, False,
#          True, False,  True, False, False, False, False,  True, False,
#          True, False, False,  True,  True, False, False,  True,  True,
#         False, False, False, False, False, False,  True, False, False,
#         False, False, False, False, False,  True, False, False, False,
#          True,  True,  True, False, False, False, False,  True,  True,
#         False, False, False, False,  True, False, False, False, False,
#         False, False,  True, False, False, False,  True, False, False,
#         False, False, False,  True, False, False, False, False,  True,
#          True, False,  True,  True, False,  True, False, False,  True,
#         False, False, False, False, False, False, False, False, False,
#          True,  True, False, False, False, False,  True, False, False,
#          True,  True, False, False, False, False,  True, False,  True,
#         False, False, False, False, False,  True,  True, False,  True,
#         False, False, False, False, False,  True,  True, False, False,
#         False,  True,  True, False, False, False, False,  True, False,
#         False, False,  True,  True, False,  True,  True, False,  True,
#         False, False,  True, False, False,  True,  True, False, False,
#          True, False,  True,  True, False,  True, False,  True, False,
#          True, False, False, False, False, False, False,  True, False,
#         False, False, False,  True, False, False, False,  True, False,
#          True, False, False, False, False,  True, False, False, False,
#          True, False, False,  True, False, False, False, False, False,
#          True,  True, False, False, False, False, False, False, False,
#         False, False, False, False,  True, False, False, False, False,
#         False,  True,  True, False,  True, False, False,  True, False,
#         False, False, False, False, False, False, False, False, False,
#         False,  True, False,  True,  True,  True, False,  True,  True,
#          True, False,  True, False, False,  True, False, False,  True,
#         False,  True, False, False, False, False, False, False, False,
#          True, False,  True, False, False, False,  True, False, False,
#         False, False, False, False, False, False, False, False,  True,
#          True, False, False,  True,  True,  True, False,  True, False,
#         False,  True, False, False, False,  True, False,  True, False,
#          True, False, False, False, False, False,  True, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False,  True, False,  True,
#         False, False, False, False, False,  True, False,  True,  True,
#         False,  True,  True, False, False,  True, False, False, False,
#          True, False, False,  True, False, False, False, False, False,
#         False, False, False,  True, False, False, False, False,  True,
#          True, False, False, False, False,  True, False, False, False,
#         False, False,  True,  True, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#          True,  True,  True,  True, False, False, False,  True,  True,
#         False, False, False,  True, False, False,  True,  True, False,
#         False, False, False,  True, False, False,  True, False, False,
#         False, False, False, False, False, False, False,  True, False,
#          True, False, False, False, False,  True, False, False,  True,
#         False, False, False,  True, False,  True, False, False, False,
#          True, False, False, False, False,  True, False, False, False,
#          True,  True, False, False,  True,  True, False, False, False,
#         False, False, False, False, False,  True, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#          True, False, False, False, False,  True, False,  True, False,
#         False, False, False, False,  True,  True, False,  True, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False,  True,
#          True, False,  True, False, False, False, False, False, False,
#          True, False,  True,  True, False, False, False, False, False,
#         False, False, False,  True,  True, False, False,  True, False,
#         False,  True, False, False]])
